# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

nba_data_to_load = "Project #1/Kaggle_NBA_Data.csv"
nba_data_df = pd.read_csv(nba_data_to_load)
nba_data_df.head(2000)
# Out:
#         Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 0     2009.0         Alex Acker  SG  26.0  TOT  25.0   0.0   199.0  10.4
# 1     2009.0         Alex Acker  SG  26.0  DET   7.0   0.0    20.0  16.0
# 2     2009.0         Alex Acker  SG  26.0  LAC  18.0   0.0   179.0   9.8
# 3     2009.0       Hassan Adams  SG  24.0  TOR  12.0   0.0    52.0   0.4
# 4     2009.0      Arron Afflalo  SG  23.0  DET  74.0   8.0  1234.0   8.9
# 5     2009.0       Maurice Ager  SG  24.0  NJN  20.0   0.0    97.0   2.2
# 6     2009.0       Blake Ahearn  PG  24.0  SAS   3.0   0.0    19.0  12.9
# 7     2009.0      Alexis Ajinca  PF  20.0  CHA  31.0   4.0   182.0   7.0
# 8     2009.0  LaMarcus Aldridge  PF  23.0  POR  81.0  81.0  3004.0  19.1
# 9     2009.0      Joe Alexander  SF  22.0  MIL  59.0   0.0   716.0  10.1
# 10    2009.0        Malik Allen  PF  30.0  MIL  49.0   3.0   579.0   7.3
# 11    2009.0          Ray Allen  SG  33.0  BOS  79.0  79.0  2876.0  17.3
# ...

# %%
scoring = nba_data_df[["Year", "Tm", "PTS", ""]]
